# %%
# Cargamos las librerias
import ast
import pandas as pd
import numpy as np
import json

#Como el se que mi Dataset tiene muchas columnas seteo a Pandas para que me muestre todas
pd.set_option('display.max_columns', None)

# Se carga el archivo CSV dentro de un DataFrame de Pandas

df = pd.read_csv('movies_dataset.csv')
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\2854674742.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_dataset.csv')

# %%
#Realizo una exploración inicial de los datos
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %%
# Como observamos algunas columnas tienen diccionarios empaquetados en formato de listas "[]", procedo a eliminar los corchetes.

df['belongs_to_collection'] = df['belongs_to_collection'].astype(str).str.replace('[','').str.replace(']','')
df['genres'] = df['genres'].astype(str).str.replace('[','').str.replace(']','')
df['spoken_languages'] = df['spoken_languages'].astype(str).str.replace('[','').str.replace(']','')
df['production_companies'] = df['production_companies'].astype(str).str.replace('[','').str.replace(']','')
df['production_countries'] = df['production_countries'].astype(str).str.replace('[','').str.replace(']','')

df.head(2)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\1159837356.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['belongs_to_collection'] = df['belongs_to_collection'].astype(str).str.replace('[','').str.replace(']','')
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\1159837356.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['genres'] = df['genres'].astype(str).str.replace('[','').str.replace(']','')
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\1159837356.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['spoken_languages'] = df['spoken_languages'].astype(str).str.replace('[','').str.replace(']','')
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\1159837356.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['production_companies'] = df['production_companies'].astype(str).str.replace('[','').str.replace(']','')
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13380\1159837356.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['production_countries'] = df['production_countries'].astype(str).str.replace('[','').str.replace(']','')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                nan  65000000
#
#                                               genres  \
# 0  {'id': 16, 'name': 'Animation'}, {'id': 35, 'n...
# 1  {'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0       {'name': 'Pixar Animation Studios', 'id': 3}
# 1  {'name': 'TriStar Pictures', 'id': 559}, {'nam...
#
#                                 production_countries release_date  \
# 0  {'iso_3166_1': 'US', 'name': 'United States of...   1995-10-30
# 1  {'iso_3166_1': 'US', 'name': 'United States of...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0             {'iso_639_1': 'en', 'name': 'English'}
# 1  262797249.0    104.0  {'iso_639_1': 'en', 'name': 'English'}, {'iso_...
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %%
# Creo una funcion que me permita estandarizar los datos que se encuentran como diccionario en diferentes columnas a formato JSON, para posteriormente desempaquetarlos.
# En formato JSON las claves y valor van entre comillas dobles
# En esta misma funcion aprovecho para que si encuentra valores faltantes devuelva 0


def fix_json(x):
    try:
        d = json.loads(x.replace("'", "\""))
        return json.dumps({str(k): str(v) for k,v in d.items()})
    except:
        return 0

# %%
#Aplico la funcion a las columnas que me intereza estandarizar

df['belongs_to_collection'] = df['belongs_to_collection'].apply(fix_json)
df['genres'] = df['genres'].apply(fix_json)
df['spoken_languages'] = df['spoken_languages'].apply(fix_json)
df['production_companies'] = df['production_companies'].apply(fix_json)
df['production_countries'] = df['production_countries'].apply(fix_json)

df.head(2)
# Out:
#    adult                              belongs_to_collection    budget genres  \
# 0  False  {"id": "10194", "name": "Toy Story Collection"...  30000000      0
# 1  False                                                  0  65000000      0
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                              production_companies  \
# 0  {"name": "Pixar Animation Studios", "id": "3"}
# 1                                               0
#
#                                 production_countries release_date  \
# 0  {"iso_3166_1": "US", "name": "United States of...   1995-10-30
# 1  {"iso_3166_1": "US", "name": "United States of...   1995-12-15
#
#        revenue  runtime                        spoken_languages    status  \
# 0  373554033.0     81.0  {"iso_639_1": "en", "name": "English"}  Released
# 1  262797249.0    104.0                                       0  Released
#
#                                      tagline      title  video  vote_average  \
# 0                                        NaN  Toy Story  False           7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False           6.9
#
#    vote_count
# 0      5415.0
# 1      2413.0

# %%
from pandas import json_normalize

# Aplico un funcion lambda y convierto los datos de columnas que tienen formato JSON a un diccionario, comprobando si el valor esta en formato de string, si no lo esta los empaqueta en un diccionario vaico
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: json.loads(x) if isinstance(x, str) else {})
df['genres'] = df['genres'].apply(lambda x: json.loads(x) if isinstance(x, str) else {})
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: json.loads(x) if isinstance(x, str) else {})
df['production_companies'] = df['production_companies'].apply(lambda x: json.loads(x) if isinstance(x, str) else {})
df['production_countries'] = df['production_countries'].apply(lambda x: json.loads(x) if isinstance(x, str) else {})

# Desanido los datos y agregar nuevas columnas al DataFrame
df = pd.concat([df.drop(['belongs_to_collection'], axis=1),
                json_normalize(df['belongs_to_collection']).add_prefix('belongs_to_collection_')],
               axis=1)
df = pd.concat([df.drop(['genres'], axis=1),
                json_normalize(df['genres']).add_prefix('genres_')],
               axis=1)
df = pd.concat([df.drop(['spoken_languages'], axis=1),
                json_normalize(df['spoken_languages']).add_prefix('spoken_languages_')],
               axis=1)
df = pd.concat([df.drop(['production_companies'], axis=1),
                json_normalize(df['production_companies']).add_prefix('production_companies_')],
               axis=1)
df = pd.concat([df.drop(['production_countries'], axis=1),
                json_normalize(df['production_countries']).add_prefix('production_countries_')],
               axis=1)


df.head(2)
# Out:
#    adult    budget                              homepage    id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story   862  tt0114709
# 1  False  65000000                                   NaN  8844  tt0113497
#
#   original_language original_title  \
# 0                en      Toy Story
# 1                en        Jumanji
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                         poster_path release_date      revenue  runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373554033.0     81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262797249.0    104.0
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#    vote_average  vote_count belongs_to_collection_id  \
# 0           7.7      5415.0                    10194
# 1           6.9      2413.0                      NaN
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                        NaN                               NaN
#
#   belongs_to_collection_backdrop_path genres_id genres_name  \
# 0    /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg       NaN         NaN
# 1                                 NaN       NaN         NaN
#
#   spoken_languages_iso_639_1 spoken_languages_name production_companies_name  \
# 0                         en               English   Pixar Animation Studios
# 1                        NaN                   NaN                       NaN
#
#   production_companies_id production_countries_iso_3166_1  \
# 0                       3                              US
# 1                     NaN                              US
#
#   production_countries_name
# 0  United States of America
# 1  United States of America

# %%
# Reviso que columnas tienen valores faltantes y su cantidad
df.isnull().sum()
# Out:
# adult                                      0
# budget                                     0
# homepage                               37684
# id                                         0
# imdb_id                                   17
# original_language                         11
# original_title                             0
# overview                                 954
# popularity                                 5
# poster_path                              386
# release_date                              87
# revenue                                    6
# runtime                                  263
# status                                    87
# tagline                                25054
# title                                      6
# video                                      6
# vote_average                               6
# vote_count                                 6
# belongs_to_collection_id               42298
# belongs_to_collection_name             42298
# belongs_to_collection_poster_path      42298
# belongs_to_collection_backdrop_path    42298
# genres_id                              30907
# genres_name                            30907
# spoken_languages_iso_639_1             11739
# spoken_languages_name                  11739
# production_companies_name              28983
# production_companies_id                28983
# production_countries_iso_3166_1        13316
# production_countries_name              13316
# dtype: int64

# %%
# Remplazo los valores faltantes en las columnas solicitadas por 0
df['revenue'].fillna(0, inplace=True)
df['budget'].fillna(0, inplace=True)

# %%
# Convierto la columna a formato fecha
df["release_date"]= pd.to_datetime(df['release_date'], errors= "coerce").dt.strftime('%Y-%m-%d')

# %%
# Elimino las filas que tienen valor faltante en la columna release_date
df = df.dropna(subset=['release_date'])
df.isnull().sum()
# Out:
# adult                                      0
# budget                                     0
# homepage                               37610
# id                                         0
# imdb_id                                   14
# original_language                         11
# original_title                             0
# overview                                 941
# popularity                                 0
# poster_path                              339
# release_date                               0
# revenue                                    0
# runtime                                  246
# status                                    80
# tagline                                24978
# title                                      0
# video                                      0
# vote_average                               0
# vote_count                                 0
# belongs_to_collection_id               42211
# belongs_to_collection_name             42211
# belongs_to_collection_poster_path      42211
# belongs_to_collection_backdrop_path    42211
# genres_id                              30829
# genres_name                            30829
# spoken_languages_iso_639_1             11670
# spoken_languages_name                  11670
# production_companies_name              28893
# production_companies_id                28893
# production_countries_iso_3166_1        13238
# production_countries_name              13238
# dtype: int64

# %%
# Creao la columna release_year
df['release_year'] = pd.to_datetime(df['release_date'], errors='coerce').dt.year

# %%
    
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path release_date      revenue  runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373554033.0     81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262797249.0    104.0
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22          0.0    101.0
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22   81452156.0    127.0
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10   76578911.0    106.0
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0
#
#   belongs_to_collection_id      belongs_to_collection_name  \
# 0                    10194            Toy Story Collection
# 1                      NaN                             NaN
# 2                   119050       Grumpy Old Men Collection
# 3                      NaN                             NaN
# 4                    96871  Father of the Bride Collection
#
#   belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg    /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN                                 NaN
# 2  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg    /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN                                 NaN
# 4  /nts4iOmNnq7GNicycMJ9pSAn204.jpg    /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
#
#   genres_id genres_name spoken_languages_iso_639_1 spoken_languages_name  \
# 0       NaN         NaN                         en               English
# 1       NaN         NaN                        NaN                   NaN
# 2       NaN         NaN                         en               English
# 3       NaN         NaN                         en               English
# 4        35      Comedy                         en               English
#
#                 production_companies_name production_companies_id  \
# 0                 Pixar Animation Studios                       3
# 1                                     NaN                     NaN
# 2                                     NaN                     NaN
# 3  Twentieth Century Fox Film Corporation                     306
# 4                                     NaN                     NaN
#
#   production_countries_iso_3166_1 production_countries_name  release_year
# 0                              US  United States of America          1995
# 1                              US  United States of America          1995
# 2                              US  United States of America          1995
# 3                              US  United States of America          1995
# 4                              US  United States of America          1995

# %%
#Convierto los datos de las columnas a formato numerico y le agrego que si por alguna razón encuentra un dato que no se pueda convertir lo setee como NaN y posteriormente esos valores los convierta en 0

df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['revenue'].fillna(0, inplace=True)
df['budget'].fillna(0, inplace=True)

#Creo la columna return como fue solicitada
df['return'] = df.apply(lambda row: 0 if row['budget'] == 0 else row['revenue'] / row['budget'], axis=1)

# %%
df.head(2)
# Out:
#    adult    budget                              homepage    id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story   862  tt0114709
# 1  False  65000000                                   NaN  8844  tt0113497
#
#   original_language original_title  \
# 0                en      Toy Story
# 1                en        Jumanji
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                         poster_path release_date      revenue  runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373554033.0     81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262797249.0    104.0
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#    vote_average  vote_count belongs_to_collection_id  \
# 0           7.7      5415.0                    10194
# 1           6.9      2413.0                      NaN
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                        NaN                               NaN
#
#   belongs_to_collection_backdrop_path genres_id genres_name  \
# 0    /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg       NaN         NaN
# 1                                 NaN       NaN         NaN
#
#   spoken_languages_iso_639_1 spoken_languages_name production_companies_name  \
# 0                         en               English   Pixar Animation Studios
# 1                        NaN                   NaN                       NaN
#
#   production_companies_id production_countries_iso_3166_1  \
# 0                       3                              US
# 1                     NaN                              US
#
#   production_countries_name  release_year     return
# 0  United States of America          1995  12.451801
# 1  United States of America          1995   4.043035

# %%
df.to_csv("Data_ML.csv", index=False)

# %%
# Elimino las columnas solicitadas
df.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'vote_count', 'poster_path', 'homepage'], inplace=True)

# %%
#Por ultimo modifico el orden de la columnas
cols = df.columns.tolist()

# %%
cols = ['budget','revenue','return',
 'id','title', 'release_date', 'release_year',
 'original_language',
 'overview',
 'popularity',
 'runtime',
 'status',
 'tagline',
 'vote_average',
 'belongs_to_collection_id',
 'belongs_to_collection_name',
 'belongs_to_collection_poster_path',
 'belongs_to_collection_backdrop_path',
 'genres_id',
 'genres_name',
 'spoken_languages_iso_639_1',
 'spoken_languages_name',
 'production_companies_id',
 'production_companies_name',
 'production_countries_iso_3166_1',
 'production_countries_name'
 ]
df = df[cols]

# %%
df.head(20)
# Out:
#       budget      revenue     return     id                           title  \
# 0   30000000  373554033.0  12.451801    862                       Toy Story
# 1   65000000  262797249.0   4.043035   8844                         Jumanji
# 2          0          0.0   0.000000  15602                Grumpier Old Men
# 3   16000000   81452156.0   5.090760  31357               Waiting to Exhale
# 4          0   76578911.0   0.000000  11862     Father of the Bride Part II
# 5   60000000  187436818.0   3.123947    949                            Heat
# 6   58000000          0.0   0.000000  11860                         Sabrina
# 7          0          0.0   0.000000  45325                    Tom and Huck
# 8   35000000   64350171.0   1.838576   9091                    Sudden Death
# 9   58000000  352194034.0   6.072311    710                       GoldenEye
# 10  62000000  107879496.0   1.739992   9087          The American President
# 11         0          0.0   0.000000  12110     Dracula: Dead and Loving It
# 12         0   11348324.0   0.000000  21032                           Balto
# 13  44000000   13681765.0   0.310949  10858                           Nixon
# 14  98000000   10017322.0   0.102218   1408                Cutthroat Island
# 15  52000000  116112375.0   2.232930    524                          Casino
# 16  16500000  135000000.0   8.181818   4584           Sense and Sensibility
# 17   4000000    4300000.0   1.075000      5                      Four Rooms
# 18  30000000  212385533.0   7.079518   9273  Ace Ventura: When Nature Calls
# 19  60000000   35431113.0   0.590519  11517                     Money Train
#
#    release_date  release_year original_language  \
# 0    1995-10-30          1995                en
# 1    1995-12-15          1995                en
# 2    1995-12-22          1995                en
# 3    1995-12-22          1995                en
# 4    1995-02-10          1995                en
# 5    1995-12-15          1995                en
# 6    1995-12-15          1995                en
# 7    1995-12-22          1995                en
# 8    1995-12-22          1995                en
# 9    1995-11-16          1995                en
# 10   1995-11-17          1995                en
# 11   1995-12-22          1995                en
# 12   1995-12-22          1995                en
# 13   1995-12-22          1995                en
# 14   1995-12-22          1995                en
# 15   1995-11-22          1995                en
# 16   1995-12-13          1995                en
# 17   1995-12-09          1995                en
# 18   1995-11-10          1995                en
# 19   1995-11-21          1995                en
#
#                                              overview popularity  runtime  \
# 0   Led by Woody, Andy's toys live happily in his ...  21.946943     81.0
# 1   When siblings Judy and Peter discover an encha...  17.015539    104.0
# 2   A family wedding reignites the ancient feud be...    11.7129    101.0
# 3   Cheated on, mistreated and stepped on, the wom...   3.859495    127.0
# 4   Just when George Banks has recovered from his ...   8.387519    106.0
# 5   Obsessive master thief, Neil McCauley leads a ...  17.924927    170.0
# 6   An ugly duckling having undergone a remarkable...   6.677277    127.0
# 7   A mischievous young boy, Tom Sawyer, witnesses...   2.561161     97.0
# 8   International action superstar Jean Claude Van...    5.23158    106.0
# 9   James Bond must unmask the mysterious head of ...  14.686036    130.0
# 10  Widowed U.S. president Andrew Shepherd, one of...   6.318445    106.0
# 11  When a lawyer shows up at the vampire's doorst...   5.430331     88.0
# 12  An outcast half-wolf risks his life to prevent...  12.140733     78.0
# 13  An all-star cast powers this epic look at Amer...      5.092    192.0
# 14  Morgan Adams and her slave, William Shaw, are ...   7.284477    119.0
# 15  The life of the gambling paradise – Las Vegas ...  10.137389    178.0
# 16  Rich Mr. Dashwood dies, leaving his second wif...  10.673167    136.0
# 17  It's Ted the Bellhop's first night on the job....   9.026586     98.0
# 18  Summoned from an ashram in Tibet, Ace finds hi...   8.205448     90.0
# 19  A vengeful New York transit cop decides to ste...   7.337906    103.0
#
#       status                                            tagline  vote_average  \
# 0   Released                                                NaN           7.7
# 1   Released          Roll the dice and unleash the excitement!           6.9
# 2   Released  Still Yelling. Still Fighting. Still Ready for...           6.5
# 3   Released  Friends are the people who let you be yourself...           6.1
# 4   Released  Just When His World Is Back To Normal... He's ...           5.7
# 5   Released                           A Los Angeles Crime Saga           7.7
# 6   Released  You are cordially invited to the most surprisi...           6.2
# 7   Released                             The Original Bad Boys.           5.4
# 8   Released                         Terror goes into overtime.           5.5
# 9   Released               No limits. No fears. No substitutes.           6.6
# 10  Released  Why can't the most powerful man in the world h...           6.5
# 11  Released                                                NaN           5.7
# 12  Released                     Part Dog. Part Wolf. All Hero.           7.1
# 13  Released  Triumphant in Victory, Bitter in Defeat. He Ch...           7.1
# 14  Released  The Course Has Been Set. There Is No Turning B...           5.7
# 15  Released                   No one stays at the top forever.           7.8
# 16  Released           Lose your heart and come to your senses.           7.2
# 17  Released  Twelve outrageous guests. Four scandalous requ...           6.5
# 18  Released            New animals. New adventures. Same hair.           6.1
# 19  Released                        Get on, or GET OUT THE WAY!           5.4
#
#    belongs_to_collection_id      belongs_to_collection_name  \
# 0                     10194            Toy Story Collection
# 1                       NaN                             NaN
# 2                    119050       Grumpy Old Men Collection
# 3                       NaN                             NaN
# 4                     96871  Father of the Bride Collection
# 5                       NaN                             NaN
# 6                       NaN                             NaN
# 7                       NaN                             NaN
# 8                       NaN                             NaN
# 9                       645           James Bond Collection
# 10                      NaN                             NaN
# 11                      NaN                             NaN
# 12                   117693                Balto Collection
# 13                      NaN                             NaN
# 14                      NaN                             NaN
# 15                      NaN                             NaN
# 16                      NaN                             NaN
# 17                      NaN                             NaN
# 18                     3167          Ace Ventura Collection
# 19                      NaN                             NaN
#
#    belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0   /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg    /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                                NaN                                 NaN
# 2   /nLvUdqgPgm3F85NMCii9gVFUcet.jpg    /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                                NaN                                 NaN
# 4   /nts4iOmNnq7GNicycMJ9pSAn204.jpg    /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7                                NaN                                 NaN
# 8                                NaN                                 NaN
# 9    /HORpg5CSkmeQlAolx3bKMrKgfi.jpg    /6VcVl48kNKvdXOZfJPdarlUGOsk.jpg
# 10                               NaN                                 NaN
# 11                               NaN                                 NaN
# 12  /w0ZgH6Lgxt2bQYnf1ss74UvYftm.jpg    /9VM5LiJV0bGb1st1KyHA3cVnO2G.jpg
# 13                               NaN                                 NaN
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17                               NaN                                 NaN
# 18  /qCxH543pScFed1CycwJ1nVgrkOc.jpg    /bswWgdDsLu0fhWMYUzLF8XgiK4h.jpg
# 19                               NaN                                 NaN
#
#    genres_id genres_name spoken_languages_iso_639_1 spoken_languages_name  \
# 0        NaN         NaN                         en               English
# 1        NaN         NaN                        NaN                   NaN
# 2        NaN         NaN                         en               English
# 3        NaN         NaN                         en               English
# 4         35      Comedy                         en               English
# 5        NaN         NaN                        NaN                   NaN
# 6        NaN         NaN                        NaN                   NaN
# 7        NaN         NaN                        NaN                   NaN
# 8        NaN         NaN                         en               English
# 9        NaN         NaN                        NaN                   NaN
# 10       NaN         NaN                         en               English
# 11       NaN         NaN                        NaN                   NaN
# 12       NaN         NaN                         en               English
# 13       NaN         NaN                         en               English
# 14       NaN         NaN                        NaN                   NaN
# 15       NaN         NaN                         en               English
# 16       NaN         NaN                         en               English
# 17       NaN         NaN                         en               English
# 18       NaN         NaN                         en               English
# 19       NaN         NaN                         en               English
#
#    production_companies_id               production_companies_name  \
# 0                        3                 Pixar Animation Studios
# 1                      NaN                                     NaN
# 2                      NaN                                     NaN
# 3                      306  Twentieth Century Fox Film Corporation
# 4                      NaN                                     NaN
# 5                      NaN                                     NaN
# 6                      NaN                                     NaN
# 7                        2                    Walt Disney Pictures
# 8                      NaN                                     NaN
# 9                      NaN                                     NaN
# 10                     NaN                                     NaN
# 11                     NaN                                     NaN
# 12                     NaN                                     NaN
# 13                     NaN                                     NaN
# 14                     NaN                                     NaN
# 15                     NaN                                     NaN
# 16                     NaN                                     NaN
# 17                     NaN                                     NaN
# 18                     NaN                                     NaN
# 19                       5                       Columbia Pictures
#
#    production_countries_iso_3166_1 production_countries_name
# 0                               US  United States of America
# 1                               US  United States of America
# 2                               US  United States of America
# 3                               US  United States of America
# 4                               US  United States of America
# 5                               US  United States of America
# 6                              NaN                       NaN
# 7                               US  United States of America
# 8                               US  United States of America
# 9                              NaN                       NaN
# 10                              US  United States of America
# 11                             NaN                       NaN
# 12                              US  United States of America
# 13                              US  United States of America
# 14                             NaN                       NaN
# 15                             NaN                       NaN
# 16                             NaN                       NaN
# 17                              US  United States of America
# 18                              US  United States of America
# 19                              US  United States of America

# %%
df.to_csv("data_limpia.csv", index=False)
df.to_excel("data_limpia.xlsx", index=False)
